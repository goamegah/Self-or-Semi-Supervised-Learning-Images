# %%
from numpy.random import randint
import numpy as np

import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten
from keras.datasets.mnist import load_data
from keras.layers import Dropout
from keras.optimizers import Adam

# %%
def get_images_ready(n_classes=10):
  (x_train, y_train), (_, _) = load_data()
  x = np.expand_dims(x_train, axis=-1)
  x = x.astype('float32')
  x = x/255.
  print(x.shape, y_train)
  return [x, y_train]

# %%
num_images = 120
def select_subset_images(dataset, n_samples=num_images, n_classes=10):
  x, y = dataset
  x_list, y_list = list(), list()
  n_per_class = int(n_samples/n_classes)
  for i in range(n_classes):
    x_with_class = x[y==i]
    ix = randint(0, len(x_with_class), n_per_class)
    [x_list.append(x_with_class[j]) for j in ix]
    [y_list.append(i) for j in ix]
  return np.asarray(x_list), np.asarray(y_list)

# %%
dataset = get_images_ready()
x, y = select_subset_images(dataset)
# Out:
# (60000, 28, 28, 1) [5 0 4 ... 5 6 8]

# %%
i = randint(0, x.shape[0])
plt.imshow(x[i])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.16, random_state=42)

# %%
print('x_train : ',x_train.shape,'\nx_test : ',x_test.shape)
# Out:
# x_train :  (100, 28, 28, 1)
# x_test :  (20, 28, 28, 1)

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), strides=(2,2), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3,3), strides=(2,2), padding='same', activation='relu'))
model.add(Conv2D(128, (3,3), strides=(2,2), padding='same', activation='relu'))

model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

# %%
opt = Adam(learning_rate=0.0002, beta_1=0.5)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 13, 13, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          18496
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 10)                20490
#
# =================================================================
# Total params: 113162 (442.04 KB)
# Trainable params: 113162 (442.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=50, validation_data=(x_test, y_test), verbose=1)

model.save('cnn_model_for_mnist_100epochs.h5')
# Out:
# Epoch 1/100
# 2/2 [==============================] - 2s 391ms/step - loss: 2.2731 - accuracy: 0.1100 - val_loss: 2.2766 - val_accuracy: 0.1500
# Epoch 2/100
# 2/2 [==============================] - 0s 108ms/step - loss: 2.2669 - accuracy: 0.1500 - val_loss: 2.2582 - val_accuracy: 0.1500
# Epoch 3/100
# 2/2 [==============================] - 0s 105ms/step - loss: 2.2116 - accuracy: 0.2800 - val_loss: 2.2385 - val_accuracy: 0.2000
# Epoch 4/100
# 2/2 [==============================] - 0s 77ms/step - loss: 2.1778 - accuracy: 0.3200 - val_loss: 2.2163 - val_accuracy: 0.2000
# Epoch 5/100
# 2/2 [==============================] - 0s 121ms/step - loss: 2.1620 - accuracy: 0.3300 - val_loss: 2.1933 - val_accuracy: 0.3000
# Epoch 6/100
# 2/2 [==============================] - 0s 94ms/step - loss: 2.1049 - accuracy: 0.4600 - val_loss: 2.1657 - val_accuracy: 0.3000
# Epoch 7/100
# 2/2 [==============================] - 0s 98ms/step - loss: 2.0805 - accuracy: 0.4500 - val_loss: 2.1374 - val_accuracy: 0.3000
# Epoch 8/100
# 2/2 [==============================] - 0s 84ms/step - loss: 2.0449 - accuracy: 0.4100 - val_loss: 2.1069 - val_accuracy: 0.4000
# Epoch 9/100
# 2/2 [==============================] - 0s 88ms/step - loss: 1.9787 - accuracy: 0.6200 - val_loss: 2.0741 - val_accuracy: 0.4000
# Epoch 10/100
# 2/2 [==============================] - 0s 85ms/step - loss: 1.9556 - accuracy: 0.5700 - val_loss: 2.0381 - val_accuracy: 0.4500
# Epoch 11/100
# 2/2 [==============================] - 0s 81ms/step - loss: 1.8798 - accuracy: 0.6300 - val_loss: 1.9918 - val_accuracy: 0.4500
# Epoch 12/100
# 2/2 [==============================] - 0s 45ms/step - loss: 1.8329 - accuracy: 0.7200 - val_loss: 1.9445 - val_accuracy: 0.5000
# Epoch 13/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1.7675 - accuracy: 0.7500 - val_loss: 1.8908 - val_accuracy: 0.5000
# Epoch 14/100
# 2/2 [==============================] - 0s 58ms/step - loss: 1.7491 - accuracy: 0.6800 - val_loss: 1.8391 - val_accuracy: 0.6000
# Epoch 15/100
# 2/2 [==============================] - 0s 139ms/step - loss: 1.6127 - accuracy: 0.7800 - val_loss: 1.7759 - val_accuracy: 0.6500
# Epoch 16/100
# 2/2 [==============================] - 0s 94ms/step - loss: 1.5808 - accuracy: 0.7500 - val_loss: 1.7083 - val_accuracy: 0.6500
# Epoch 17/100
# 2/2 [==============================] - 0s 231ms/step - loss: 1.4724 - accuracy: 0.8100 - val_loss: 1.6392 - val_accuracy: 0.6500
# Epoch 18/100
# 2/2 [==============================] - 0s 98ms/step - loss: 1.4398 - accuracy: 0.7800 - val_loss: 1.5670 - val_accuracy: 0.6500
# Epoch 19/100
# 2/2 [==============================] - 0s 82ms/step - loss: 1.3291 - accuracy: 0.8300 - val_loss: 1.4960 - val_accuracy: 0.7000
# Epoch 20/100
# 2/2 [==============================] - 0s 82ms/step - loss: 1.2684 - accuracy: 0.8000 - val_loss: 1.4152 - val_accuracy: 0.7500
# Epoch 21/100
# 2/2 [==============================] - 0s 158ms/step - loss: 1.1977 - accuracy: 0.8100 - val_loss: 1.3387 - val_accuracy: 0.7500
# Epoch 22/100
# 2/2 [==============================] - 0s 142ms/step - loss: 1.1007 - accuracy: 0.8400 - val_loss: 1.2763 - val_accuracy: 0.7500
# Epoch 23/100
# 2/2 [==============================] - 0s 116ms/step - loss: 1.0279 - accuracy: 0.8800 - val_loss: 1.2196 - val_accuracy: 0.7500
# Epoch 24/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.9548 - accuracy: 0.8900 - val_loss: 1.1598 - val_accuracy: 0.7500
# Epoch 25/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.9014 - accuracy: 0.8700 - val_loss: 1.0987 - val_accuracy: 0.8000
# Epoch 26/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.8498 - accuracy: 0.9200 - val_loss: 1.0335 - val_accuracy: 0.8000
# Epoch 27/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.8162 - accuracy: 0.8800 - val_loss: 0.9805 - val_accuracy: 0.9000
# Epoch 28/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.7186 - accuracy: 0.9200 - val_loss: 0.9292 - val_accuracy: 0.9000
# Epoch 29/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6514 - accuracy: 0.9400 - val_loss: 0.8848 - val_accuracy: 0.9000
# Epoch 30/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6503 - accuracy: 0.9100 - val_loss: 0.8446 - val_accuracy: 0.9000
# Epoch 31/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.5434 - accuracy: 0.9300 - val_loss: 0.8241 - val_accuracy: 0.9000
# Epoch 32/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.5428 - accuracy: 0.9300 - val_loss: 0.8080 - val_accuracy: 0.8500
# Epoch 33/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5494 - accuracy: 0.9200 - val_loss: 0.7595 - val_accuracy: 0.8500
# Epoch 34/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.5193 - accuracy: 0.9300 - val_loss: 0.7239 - val_accuracy: 0.9000
# Epoch 35/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.4528 - accuracy: 0.9600 - val_loss: 0.7077 - val_accuracy: 0.9000
# Epoch 36/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.4471 - accuracy: 0.9000 - val_loss: 0.6730 - val_accuracy: 0.9000
# Epoch 37/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4048 - accuracy: 0.9600 - val_loss: 0.6496 - val_accuracy: 0.9000
# Epoch 38/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.3829 - accuracy: 0.9600 - val_loss: 0.6359 - val_accuracy: 0.8500
# Epoch 39/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3758 - accuracy: 0.9500 - val_loss: 0.6139 - val_accuracy: 0.8000
# Epoch 40/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.3448 - accuracy: 0.9400 - val_loss: 0.6038 - val_accuracy: 0.8500
# Epoch 41/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.3047 - accuracy: 0.9900 - val_loss: 0.5781 - val_accuracy: 0.8500
# Epoch 42/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.2893 - accuracy: 0.9900 - val_loss: 0.5580 - val_accuracy: 0.9000
# Epoch 43/100
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2750 - accuracy: 0.9900 - val_loss: 0.5454 - val_accuracy: 0.9000
# Epoch 44/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.2549 - accuracy: 0.9900 - val_loss: 0.5306 - val_accuracy: 0.9000
# Epoch 45/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.2372 - accuracy: 0.9900 - val_loss: 0.5226 - val_accuracy: 0.8500
# Epoch 46/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2640 - accuracy: 0.9700 - val_loss: 0.5205 - val_accuracy: 0.8500
# Epoch 47/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2588 - accuracy: 0.9800 - val_loss: 0.4914 - val_accuracy: 0.8500
# Epoch 48/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2393 - accuracy: 1.0000 - val_loss: 0.4797 - val_accuracy: 0.8500
# Epoch 49/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2705 - accuracy: 0.9500 - val_loss: 0.4631 - val_accuracy: 0.9000
# Epoch 50/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.2044 - accuracy: 0.9800 - val_loss: 0.4580 - val_accuracy: 0.8500
# Epoch 51/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1944 - accuracy: 1.0000 - val_loss: 0.4571 - val_accuracy: 0.8500
# Epoch 52/100
# 2/2 [==============================] - 0s 99ms/step - loss: 0.2088 - accuracy: 0.9600 - val_loss: 0.4405 - val_accuracy: 0.8500
# Epoch 53/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1866 - accuracy: 0.9800 - val_loss: 0.4359 - val_accuracy: 0.8500
# Epoch 54/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1657 - accuracy: 0.9900 - val_loss: 0.4249 - val_accuracy: 0.8500
# Epoch 55/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.1584 - accuracy: 1.0000 - val_loss: 0.4286 - val_accuracy: 0.8500
# Epoch 56/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1620 - accuracy: 0.9700 - val_loss: 0.4220 - val_accuracy: 0.8500
# Epoch 57/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1425 - accuracy: 0.9900 - val_loss: 0.4188 - val_accuracy: 0.8000
# Epoch 58/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1680 - accuracy: 0.9800 - val_loss: 0.3966 - val_accuracy: 0.8500
# Epoch 59/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1446 - accuracy: 1.0000 - val_loss: 0.3900 - val_accuracy: 0.8500
# Epoch 60/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1642 - accuracy: 0.9800 - val_loss: 0.3834 - val_accuracy: 0.9000
# Epoch 61/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1214 - accuracy: 0.9900 - val_loss: 0.4025 - val_accuracy: 0.8000
# Epoch 62/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1039 - accuracy: 1.0000 - val_loss: 0.3885 - val_accuracy: 0.8500
# Epoch 63/100
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1178 - accuracy: 1.0000 - val_loss: 0.3751 - val_accuracy: 0.9000
# Epoch 64/100
# 2/2 [==============================] - 0s 98ms/step - loss: 0.1178 - accuracy: 0.9800 - val_loss: 0.3898 - val_accuracy: 0.8500
# Epoch 65/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1461 - accuracy: 0.9700 - val_loss: 0.3945 - val_accuracy: 0.8500
# Epoch 66/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1185 - accuracy: 0.9700 - val_loss: 0.3940 - val_accuracy: 0.8500
# Epoch 67/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1013 - accuracy: 1.0000 - val_loss: 0.3809 - val_accuracy: 0.8500
# Epoch 68/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1321 - accuracy: 1.0000 - val_loss: 0.3628 - val_accuracy: 0.8500
# Epoch 69/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0861 - accuracy: 0.9900 - val_loss: 0.3423 - val_accuracy: 0.9000
# Epoch 70/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1018 - accuracy: 0.9900 - val_loss: 0.3512 - val_accuracy: 0.9000
# Epoch 71/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0729 - accuracy: 1.0000 - val_loss: 0.3732 - val_accuracy: 0.8500
# Epoch 72/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.1076 - accuracy: 1.0000 - val_loss: 0.3623 - val_accuracy: 0.8500
# Epoch 73/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 0.3519 - val_accuracy: 0.8500
# Epoch 74/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0912 - accuracy: 0.9900 - val_loss: 0.3600 - val_accuracy: 0.8500
# Epoch 75/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0922 - accuracy: 0.9900 - val_loss: 0.3683 - val_accuracy: 0.8500
# Epoch 76/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0846 - accuracy: 1.0000 - val_loss: 0.3718 - val_accuracy: 0.8500
# Epoch 77/100
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0841 - accuracy: 0.9900 - val_loss: 0.3471 - val_accuracy: 0.8500
# Epoch 78/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0692 - accuracy: 1.0000 - val_loss: 0.3512 - val_accuracy: 0.8500
# Epoch 79/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0799 - accuracy: 1.0000 - val_loss: 0.3577 - val_accuracy: 0.8500
# Epoch 80/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 0.3452 - val_accuracy: 0.8500
# Epoch 81/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0748 - accuracy: 0.9900 - val_loss: 0.3590 - val_accuracy: 0.8500
# Epoch 82/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0641 - accuracy: 0.9900 - val_loss: 0.3587 - val_accuracy: 0.8500
# Epoch 83/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.3308 - val_accuracy: 0.8500
# Epoch 84/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0781 - accuracy: 0.9900 - val_loss: 0.3240 - val_accuracy: 0.8500
# Epoch 85/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0629 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.8000
# Epoch 86/100
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0775 - accuracy: 0.9900 - val_loss: 0.3282 - val_accuracy: 0.8500
# Epoch 87/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0560 - accuracy: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.8500
# Epoch 88/100
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 0.8500
# Epoch 89/100
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0626 - accuracy: 1.0000 - val_loss: 0.2963 - val_accuracy: 0.8500
# Epoch 90/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.3059 - val_accuracy: 0.9000
# Epoch 91/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0659 - accuracy: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9000
# Epoch 92/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.3247 - val_accuracy: 0.8000
# Epoch 93/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0497 - accuracy: 1.0000 - val_loss: 0.3090 - val_accuracy: 0.8500
# Epoch 94/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.8500
# Epoch 95/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.3061 - val_accuracy: 0.8500
# Epoch 96/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0437 - accuracy: 1.0000 - val_loss: 0.3335 - val_accuracy: 0.8500
# Epoch 97/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.3117 - val_accuracy: 0.8500
# Epoch 98/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.3086 - val_accuracy: 0.8500
# Epoch 99/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.3281 - val_accuracy: 0.8000
# Epoch 100/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.3009 - val_accuracy: 0.8500
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model
# load the model
my_model = load_model('cnn_model_for_mnist_100epochs.h5')

# load the dataset
(_, _), (test_X, test_y) = load_data()

# expand to 3d, e.g. add channels
test_X = np.expand_dims(test_X, axis=-1)

# convert from ints to floats
test_X = test_X.astype('float32')

# scale from [0,255] to [-1,1]
test_X = test_X /255.

# evaluate the model
_, test_acc = my_model.evaluate(test_X, test_y, verbose=0)
print('Test Accuracy: %.3f%%' % (test_acc * 100))


# Predicting the Test set results
y_pred_test = model.predict(test_X)
prediction_test = np.argmax(y_pred_test, axis=1)

# Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(test_y, prediction_test)
accuracy = np.trace(cm) / float(np.sum(cm))
misclass = 1 - accuracy
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(12, 8))
sns.heatmap(cm, fmt=".3f", annot=True)
plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
plt.show()
# Out:
# Test Accuracy: 79.950%
# 313/313 [==============================] - 2s 5ms/step
